# %%
# Ensure python 3 compatibility
from __future__ import division, print_function, absolute_import

# Import necessary libraries:
# General utilities:
import sys
import os
import math

# Computation:
import numpy as np
import h5py

# Visualization:
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import ipywidgets as widgets

from IPython.display import display

# Finally, pycroscopy itself
import pycroscopy as px

from os.path import join as pjoin

# set up notebook to show plots within the notebook
% matplotlib inline

import glob

#import moviepy.video.io.ImageSequenceClip
#try:
#    output = subprocess.check_output(['ffmpeg', '-version'])
#    version = output.split(b'\n')[0].split()[2]
#    print('Found: ffmpeg v{}'.format(version.decode('utf-8')))
#    ffmpeg_installed = True
#except:
 #   ffmpeg_installed = False

# %%
# %%file custom.mplstyle
#
# axes.linewidth: 1.5
# xtick.major.size: 6
# xtick.minor.size: 2
# xtick.major.width: 1.5
# xtick.minor.width: 1.5
# ytick.major.size: 6
# ytick.minor.size: 2
# ytick.major.width: 1.5
# ytick.minor.width: 1.5
# axes.labelweight: bold
# axes.labelpad: 1
# axes.labelsize: 12
# xtick.major.pad: 1
# ytick.major.pad: 1
# xtick.labelsize: 12
# ytick.labelsize: 12
# xtick.top: True
# ytick.right: True
# xtick.direction: in
# ytick.direction: in
# image.interpolation: nearest
#
# # Loads the custom style
# plt.style.use('./custom.mplstyle')
# Out:
# Overwriting custom.mplstyle
# Overwriting custom.mplstyle

# %%
plt.style.use('./custom.mplstyle')
# Out:
# C:\Users\Josh_\Anaconda3\lib\site-packages\matplotlib\__init__.py:955: UserWarning: Illegal line #25
# 	"plt.style.use('./custom.mplstyle')"
# 	in file "./custom.mplstyle"
#   warnings.warn('Illegal %s' % error_details)
# C:\Users\Josh_\Anaconda3\lib\site-packages\matplotlib\__init__.py:955: UserWarning: Illegal line #25
# 	"plt.style.use('./custom.mplstyle')"
# 	in file "./custom.mplstyle"
#   warnings.warn('Illegal %s' % error_details)

# %%
 input_file_path ='D:/PZT001_BEPs_0003.h5' #px.io_utils.uiGetFile(caption='Select translated .h5 file or raw experiment data',
                                         #filter='Translated file (*.h5);; \\ Parameters for raw BE data (*.txt *.mat *xls *.xlsx)')

(data_dir, data_name) = os.path.split(input_file_path)

if input_file_path.endswith('.h5'):
    # No translation here
    h5_path = input_file_path
    tl = px.LabViewH5Patcher()
    hdf = tl.translate(h5_path)
else:
    # Set the data to be translated
    data_path = input_file_path

    (junk, base_name) = os.path.split(data_dir)

    # Check if the data is in the new or old format.  Initialize the correct translator for the format.
    if base_name == 'newdataformat':
        (junk, base_name) = os.path.split(junk)
        translator = px.BEPSndfTranslator(max_mem_mb=max_mem)
    else:
        translator = px.BEodfTranslator(max_mem_mb=max_mem)
    if base_name.endswith('_d'):
        base_name = base_name[:-2]
    # Translate the data
    h5_path = translator.translate(data_path, show_plots=True, save_plots=False)
    tl = px.LabViewH5Patcher()
    hdf = tl.translate(h5_path)
print('Working on:\n' + h5_path)

h5_main = px.hdf_utils.getDataSet(hdf.file, 'Raw_Data')[0]
# Out:
# File is already Pycroscopy ready.
# Working on:
# D:/PZT001_BEPs_0003.h5
# File is already Pycroscopy ready.
# Working on:
# D:/PZT001_BEPs_0003.h5

# %%
h5_sho_group = px.hdf_utils.findH5group(h5_main, 'SHO_Fit')
sho_fitter = px.BESHOmodel(h5_main, parallel=True)
if len(h5_sho_group) == 0:
    print('No SHO fit found. Doing SHO Fitting now')
    h5_sho_guess = sho_fitter.do_guess(strategy='complex_gaussian', processors=max_cores)
    h5_sho_fit = sho_fitter.do_fit(processors=max_cores)
else:
    print('Taking previous SHO results already present in file')
    h5_sho_guess = h5_sho_group[-1]['Guess']
    try:
        h5_sho_fit = h5_sho_group[-1]['Fit']
    except KeyError:
        print('Previously computed guess found. Now computing fit')
        h5_sho_fit = sho_fitter.do_fit(processors=max_cores, h5_guess=h5_sho_guess)
# Out:
# Taking previous SHO results already present in file
# Taking previous SHO results already present in file

# %%
# Specify output file path
output_file_path = './'

# If HV amplifier was used set high_voltage_amplf to 10, else to 1
high_voltage_amplf = 10

# %%
(Nd_mat, success) = px.io.hdf_utils.reshape_to_Ndims(h5_sho_fit)
print('Reshape Success = ' + str(success))
print('Nd_mat shape = ', Nd_mat.shape)

phase_offset = Nd_mat[0, 0, 1, 0, 0]['Phase [rad]']

# phase_offset = 0;

print('Phase offset [rad] = ', phase_offset)

Nd_mat[:,:,:,:,:]['Phase [rad]'] = Nd_mat[:,:,:,:,:]['Phase [rad]'] - phase_offset
# Out:
# Reshape Success = True
# Nd_mat shape =  (80, 80, 128, 2, 3)
# Phase offset [rad] =  0.342565
# Reshape Success = True
# Nd_mat shape =  (80, 80, 128, 2, 3)
# Phase offset [rad] =  0.342565

# %%
Nd_mat["Phase [rad]"].shape[2]

# %%
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'

from scipy import io
import numpy as np
import pycroscopy as px
import matplotlib.pyplot as plt
from os.path import join as pjoin
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import keras
from keras.models import Sequential, Input, Model
from keras.layers import (Dense, Conv1D, Convolution2D, GRU, LSTM, Recurrent, Bidirectional, TimeDistributed,
                          Dropout, Flatten, RepeatVector, Reshape, MaxPooling1D, UpSampling1D, BatchNormalization)
from keras.layers.core import Lambda
from keras.optimizers import Adam
import os
from os.path import join as pjoin
from keras.regularizers import l1
import sys


% matplotlib inline
# Out:
# Using TensorFlow backend.
# Using TensorFlow backend.

# %%
len(qf_on.reshape(-1))

# %%
for i in range(len(qf_on.reshape(-1))):
    if qf_on.reshape(-1)[i] > 900:
        qf_on.reshape(-1)[i] = np.mean(qf_on)
        
for i in range(len(qf_off.reshape(-1))):
    if qf_off.reshape(-1)[i] > 900:
        qf_off.reshape(-1)[i] = np.mean(qf_off)

# %%
def norm(indat):
    indat-=np.mean(indat)
    indat/=np.std(indat)
    return indat

# %%
plt.hist(qf_on.reshape(-1),100)

# %%
np.std((Nd_mat["Amplitude [V]"][:,:,:,1,2].reshape(-1)))

# %%
amp_off = np.atleast_3d(Nd_mat["Amplitude [V]"][:,:,:,1,2].reshape(-1,128))
phase_off = np.atleast_3d(Nd_mat["Phase [rad]"][:,:,:,1,2].reshape(-1,128))
freq_off = np.atleast_3d(Nd_mat["Frequency [Hz]"][:,:,:,1,2].reshape(-1,128))
qf_off = np.atleast_3d(Nd_mat["Quality Factor"][:,:,:,1,2].reshape(-1,128))

amp_on = np.atleast_3d(Nd_mat["Amplitude [V]"][:,:,:,0,2].reshape(-1,128))
phase_on = np.atleast_3d(Nd_mat["Phase [rad]"][:,:,:,0,2].reshape(-1,128))
freq_on = np.atleast_3d(Nd_mat["Frequency [Hz]"][:,:,:,0,2].reshape(-1,128))
qf_on= np.atleast_3d(Nd_mat["Quality Factor"][:,:,:,0,2].reshape(-1,128))

# %%
amp_off = np.atleast_3d(norm(amp_off))
phase_off = np.atleast_3d(norm(phase_off))
freq_off = np.atleast_3d(norm(freq_off))
qf_off = np.atleast_3d(norm(qf_off))

amp_on = np.atleast_3d(norm(amp_on))
phase_on = np.atleast_3d(norm(phase_on))
freq_on = np.atleast_3d(norm(freq_on))
qf_on= np.atleast_3d(norm(qf_on))

# %%
def make_folder(folder_name, root='./'):

    folder = pjoin(root, '{}'.format(folder_name))
    os.makedirs(folder, exist_ok=True)

    return (folder)

# %%
def encode_layer(size, numbernodes,x):
    for i in range(size-1):
        x = Bidirectional(LSTM(numbernodes, return_sequences=True))(x)
    out = Bidirectional(LSTM(numbernodes, return_sequences=False))(x)
    return out

# %%
def decode_layer(size, numbernodes,x):
    x = RepeatVector(128)(x)
    for i in range(size):
        x = Bidirectional(LSTM(numbernodes, return_sequences=True))(x)
    x = TimeDistributed(Dense(1, activation='linear'))(x)
    return x

# %%
input_on_amp = Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_off_amp =Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_on_phase =Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_off_phase =Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_on_resonance =Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_off_resonance = Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_on_loss =Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))
input_off_loss =Input(shape=(Nd_mat["Phase [rad]"].shape[2],1))


en_out_a_on = encode_layer(3,16,input_on_amp)
en_out_a_on = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_a_on)
en_out_a_off = encode_layer(3,16,input_off_amp)
en_out_a_off = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_a_off)
en_out_p_on = encode_layer(3,16,input_on_phase)
en_out_p_on = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_p_on)
en_out_p_off = encode_layer(3,16,input_off_phase)
en_out_p_off = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_p_off)
en_out_r_on = encode_layer(3,16,input_on_resonance)
en_out_r_on = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_r_on)
en_out_r_off = encode_layer(3,16,input_off_resonance)
en_out_r_off = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_r_off)
en_out_l_on = encode_layer(3,16,input_on_loss)
en_out_l_on = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_l_on)
en_out_l_off = encode_layer(3,16,input_off_loss)
en_out_l_off = Dense(4, activation='relu',activity_regularizer=l1(10e-4))(en_out_l_off)



x = keras.layers.concatenate([en_out_a_on, en_out_a_off, en_out_p_on, en_out_p_off,
                              en_out_r_on, en_out_r_off, en_out_l_on, en_out_l_off])

x = Dense(12, activation='relu',activity_regularizer=l1(10e-4))(x)

de_out_a_on = decode_layer(3,16,x)
de_out_a_off =decode_layer(3,16,x)
de_out_p_on = decode_layer(3,16,x)
de_out_p_off =decode_layer(3,16,x)
de_out_r_on = decode_layer(3,16,x)
de_out_r_off =decode_layer(3,16,x)
de_out_l_on = decode_layer(3,16,x)
de_out_l_off =decode_layer(3,16,x)

model = Model(inputs=[input_on_amp, input_off_amp, input_on_phase, input_off_phase, input_on_resonance,
                      input_off_resonance, input_on_loss, input_off_loss], 
              outputs=[de_out_a_on, de_out_a_off, de_out_p_on, de_out_p_off, de_out_r_on, de_out_r_off,
                       de_out_l_on, de_out_l_off])

model.compile(optimizer=Adam(3e-5),loss='mse')#

# %%
model = keras.models.load_model("try6/weights.54-7.96.hdf5")

# %%
Path = 'try8'
make_folder(Path)
tbCallBack = keras.callbacks.TensorBoard(
    log_dir='./' + Path, histogram_freq=0, write_graph=True, write_images=True)
filepath = './' + Path + '/weights.{epoch:02d}-{val_loss:.2f}.hdf5'
checkpoint = keras.callbacks.ModelCheckpoint(filepath, verbose=0, save_best_only=False,
                                             save_weights_only=False, mode='min', period=1)
from keras.utils import multi_gpu_model

# Replicates `model` on 2 GPUs.
# This assumes that your machine has 2 available GPUs.
#parallel_model = multi_gpu_model(model, gpus=2)
#parallel_model.compile(optimizer=Adam(3e-5),loss='mse')
model.fit([amp_off,phase_off,freq_off,qf_off, amp_on, phase_on, freq_on, qf_on], 
          [amp_off,phase_off,freq_off,qf_off, amp_on, phase_on, freq_on, qf_on],
          validation_data=([amp_off,phase_off,freq_off,qf_off, amp_on, phase_on, freq_on, qf_on], 
          [amp_off,phase_off,freq_off,qf_off, amp_on, phase_on, freq_on, qf_on]),
          epochs=20000,batch_size=1024, callbacks=[tbCallBack, checkpoint])
# Out:
# Train on 6400 samples, validate on 6400 samples
# Train on 6400 samples, validate on 6400 samples
# Epoch 1/20000
# Epoch 1/20000
# 6400/6400 [==============================] - 247s 39ms/step - loss: 7.9617 - time_distributed_1_loss: 0.9991 - time_distributed_2_loss: 0.9910 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9841 - time_distributed_6_loss: 0.9845 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9990 - val_loss: 7.9595 - val_time_distributed_1_loss: 0.9991 - val_time_distributed_2_loss: 0.9907 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9992 - val_time_distributed_5_loss: 0.9833 - val_time_distributed_6_loss: 0.9838 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9990
# 6400/6400 [==============================] - 247s 39ms/step - loss: 7.9617 - time_distributed_1_loss: 0.9991 - time_distributed_2_loss: 0.9910 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9841 - time_distributed_6_loss: 0.9845 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9990 - val_loss: 7.9595 - val_time_distributed_1_loss: 0.9991 - val_time_distributed_2_loss: 0.9907 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9992 - val_time_distributed_5_loss: 0.9833 - val_time_distributed_6_loss: 0.9838 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9990
# Epoch 2/20000
# Epoch 2/20000
# 6400/6400 [==============================] - 180s 28ms/step - loss: 7.9586 - time_distributed_1_loss: 0.9991 - time_distributed_2_loss: 0.9905 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9828 - time_distributed_6_loss: 0.9834 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9989 - val_loss: 7.9561 - val_time_distributed_1_loss: 0.9991 - val_time_distributed_2_loss: 0.9901 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9992 - val_time_distributed_5_loss: 0.9819 - val_time_distributed_6_loss: 0.9826 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9989
# 6400/6400 [==============================] - 180s 28ms/step - loss: 7.9586 - time_distributed_1_loss: 0.9991 - time_distributed_2_loss: 0.9905 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9828 - time_distributed_6_loss: 0.9834 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9989 - val_loss: 7.9561 - val_time_distributed_1_loss: 0.9991 - val_time_distributed_2_loss: 0.9901 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9992 - val_time_distributed_5_loss: 0.9819 - val_time_distributed_6_loss: 0.9826 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9989
# Epoch 3/20000
# Epoch 3/20000
# 6400/6400 [==============================] - 172s 27ms/step - loss: 7.9551 - time_distributed_1_loss: 0.9991 - time_distributed_2_loss: 0.9899 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9814 - time_distributed_6_loss: 0.9822 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9989 - val_loss: 7.9525 - val_time_distributed_1_loss: 0.9991 - val_time_distributed_2_loss: 0.9895 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9992 - val_time_distributed_5_loss: 0.9805 - val_time_distributed_6_loss: 0.9814 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9989
# 6400/6400 [==============================] - 172s 27ms/step - loss: 7.9551 - time_distributed_1_loss: 0.9991 - time_distributed_2_loss: 0.9899 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9814 - time_distributed_6_loss: 0.9822 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9989 - val_loss: 7.9525 - val_time_distributed_1_loss: 0.9991 - val_time_distributed_2_loss: 0.9895 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9992 - val_time_distributed_5_loss: 0.9805 - val_time_distributed_6_loss: 0.9814 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9989
# Epoch 4/20000
# Epoch 4/20000
# 6400/6400 [==============================] - 164s 26ms/step - loss: 7.9514 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9892 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9799 - time_distributed_6_loss: 0.9809 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9989 - val_loss: 7.9486 - val_time_distributed_1_loss: 0.9990 - val_time_distributed_2_loss: 0.9888 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9788 - val_time_distributed_6_loss: 0.9800 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9989
# 6400/6400 [==============================] - 164s 26ms/step - loss: 7.9514 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9892 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9992 - time_distributed_5_loss: 0.9799 - time_distributed_6_loss: 0.9809 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9989 - val_loss: 7.9486 - val_time_distributed_1_loss: 0.9990 - val_time_distributed_2_loss: 0.9888 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9788 - val_time_distributed_6_loss: 0.9800 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9989
# Epoch 5/20000
# Epoch 5/20000
# 6400/6400 [==============================] - 164s 26ms/step - loss: 7.9473 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9885 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9782 - time_distributed_6_loss: 0.9795 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9988 - val_loss: 7.9444 - val_time_distributed_1_loss: 0.9990 - val_time_distributed_2_loss: 0.9880 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9771 - val_time_distributed_6_loss: 0.9786 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9988
# 6400/6400 [==============================] - 164s 26ms/step - loss: 7.9473 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9885 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9782 - time_distributed_6_loss: 0.9795 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9988 - val_loss: 7.9444 - val_time_distributed_1_loss: 0.9990 - val_time_distributed_2_loss: 0.9880 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9771 - val_time_distributed_6_loss: 0.9786 - val_time_distributed_7_loss: 0.9996 - val_time_distributed_8_loss: 0.9988
# Epoch 6/20000
# Epoch 6/20000
# 6400/6400 [==============================] - 165s 26ms/step - loss: 7.9430 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9877 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9763 - time_distributed_6_loss: 0.9780 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9988 - val_loss: 7.9399 - val_time_distributed_1_loss: 0.9990 - val_time_distributed_2_loss: 0.9872 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9751 - val_time_distributed_6_loss: 0.9770 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9988
# 6400/6400 [==============================] - 165s 26ms/step - loss: 7.9430 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9877 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9763 - time_distributed_6_loss: 0.9780 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9988 - val_loss: 7.9399 - val_time_distributed_1_loss: 0.9990 - val_time_distributed_2_loss: 0.9872 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9751 - val_time_distributed_6_loss: 0.9770 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9988
# Epoch 7/20000
# Epoch 7/20000
# 6400/6400 [==============================] - 164s 26ms/step - loss: 7.9383 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9869 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9743 - time_distributed_6_loss: 0.9764 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9988 - val_loss: 7.9349 - val_time_distributed_1_loss: 0.9989 - val_time_distributed_2_loss: 0.9863 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9729 - val_time_distributed_6_loss: 0.9753 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9988
# 6400/6400 [==============================] - 164s 26ms/step - loss: 7.9383 - time_distributed_1_loss: 0.9990 - time_distributed_2_loss: 0.9869 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9743 - time_distributed_6_loss: 0.9764 - time_distributed_7_loss: 0.9996 - time_distributed_8_loss: 0.9988 - val_loss: 7.9349 - val_time_distributed_1_loss: 0.9989 - val_time_distributed_2_loss: 0.9863 - val_time_distributed_3_loss: 0.9998 - val_time_distributed_4_loss: 0.9991 - val_time_distributed_5_loss: 0.9729 - val_time_distributed_6_loss: 0.9753 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9988
# Epoch 8/20000
# Epoch 8/20000
# 6400/6400 [==============================] - 163s 25ms/step - loss: 7.9331 - time_distributed_1_loss: 0.9989 - time_distributed_2_loss: 0.9860 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9721 - time_distributed_6_loss: 0.9746 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9987 - val_loss: 7.9296 - val_time_distributed_1_loss: 0.9989 - val_time_distributed_2_loss: 0.9854 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9705 - val_time_distributed_6_loss: 0.9735 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9987
# 6400/6400 [==============================] - 163s 25ms/step - loss: 7.9331 - time_distributed_1_loss: 0.9989 - time_distributed_2_loss: 0.9860 - time_distributed_3_loss: 0.9998 - time_distributed_4_loss: 0.9991 - time_distributed_5_loss: 0.9721 - time_distributed_6_loss: 0.9746 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9987 - val_loss: 7.9296 - val_time_distributed_1_loss: 0.9989 - val_time_distributed_2_loss: 0.9854 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9705 - val_time_distributed_6_loss: 0.9735 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9987
# Epoch 9/20000
# Epoch 9/20000
# 6400/6400 [==============================] - 170s 26ms/step - loss: 7.9277 - time_distributed_1_loss: 0.9989 - time_distributed_2_loss: 0.9850 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9990 - time_distributed_5_loss: 0.9696 - time_distributed_6_loss: 0.9727 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9987 - val_loss: 7.9237 - val_time_distributed_1_loss: 0.9989 - val_time_distributed_2_loss: 0.9844 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9679 - val_time_distributed_6_loss: 0.9715 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9987
# 6400/6400 [==============================] - 170s 26ms/step - loss: 7.9277 - time_distributed_1_loss: 0.9989 - time_distributed_2_loss: 0.9850 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9990 - time_distributed_5_loss: 0.9696 - time_distributed_6_loss: 0.9727 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9987 - val_loss: 7.9237 - val_time_distributed_1_loss: 0.9989 - val_time_distributed_2_loss: 0.9844 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9679 - val_time_distributed_6_loss: 0.9715 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9987
# Epoch 10/20000
# Epoch 10/20000
# 6400/6400 [==============================] - 166s 26ms/step - loss: 7.9216 - time_distributed_1_loss: 0.9989 - time_distributed_2_loss: 0.9839 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9990 - time_distributed_5_loss: 0.9668 - time_distributed_6_loss: 0.9707 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9987 - val_loss: 7.9173 - val_time_distributed_1_loss: 0.9988 - val_time_distributed_2_loss: 0.9832 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9650 - val_time_distributed_6_loss: 0.9694 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9986
# 6400/6400 [==============================] - 166s 26ms/step - loss: 7.9216 - time_distributed_1_loss: 0.9989 - time_distributed_2_loss: 0.9839 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9990 - time_distributed_5_loss: 0.9668 - time_distributed_6_loss: 0.9707 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9987 - val_loss: 7.9173 - val_time_distributed_1_loss: 0.9988 - val_time_distributed_2_loss: 0.9832 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9650 - val_time_distributed_6_loss: 0.9694 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9986
# Epoch 11/20000
# Epoch 11/20000
# 6400/6400 [==============================] - 169s 26ms/step - loss: 7.9150 - time_distributed_1_loss: 0.9988 - time_distributed_2_loss: 0.9828 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9990 - time_distributed_5_loss: 0.9638 - time_distributed_6_loss: 0.9685 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9986 - val_loss: 7.9103 - val_time_distributed_1_loss: 0.9988 - val_time_distributed_2_loss: 0.9820 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9617 - val_time_distributed_6_loss: 0.9671 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9986
# 6400/6400 [==============================] - 169s 26ms/step - loss: 7.9150 - time_distributed_1_loss: 0.9988 - time_distributed_2_loss: 0.9828 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9990 - time_distributed_5_loss: 0.9638 - time_distributed_6_loss: 0.9685 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9986 - val_loss: 7.9103 - val_time_distributed_1_loss: 0.9988 - val_time_distributed_2_loss: 0.9820 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9990 - val_time_distributed_5_loss: 0.9617 - val_time_distributed_6_loss: 0.9671 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9986
# Epoch 12/20000
# Epoch 12/20000
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.9078 - time_distributed_1_loss: 0.9988 - time_distributed_2_loss: 0.9815 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9989 - time_distributed_5_loss: 0.9604 - time_distributed_6_loss: 0.9661 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9986 - val_loss: 7.9027 - val_time_distributed_1_loss: 0.9988 - val_time_distributed_2_loss: 0.9807 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9989 - val_time_distributed_5_loss: 0.9581 - val_time_distributed_6_loss: 0.9646 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9986
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.9078 - time_distributed_1_loss: 0.9988 - time_distributed_2_loss: 0.9815 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9989 - time_distributed_5_loss: 0.9604 - time_distributed_6_loss: 0.9661 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9986 - val_loss: 7.9027 - val_time_distributed_1_loss: 0.9988 - val_time_distributed_2_loss: 0.9807 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9989 - val_time_distributed_5_loss: 0.9581 - val_time_distributed_6_loss: 0.9646 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9986
# Epoch 13/20000
# Epoch 13/20000
# 6400/6400 [==============================] - 176s 27ms/step - loss: 7.8999 - time_distributed_1_loss: 0.9987 - time_distributed_2_loss: 0.9801 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9989 - time_distributed_5_loss: 0.9567 - time_distributed_6_loss: 0.9636 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9986 - val_loss: 7.8943 - val_time_distributed_1_loss: 0.9987 - val_time_distributed_2_loss: 0.9792 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9989 - val_time_distributed_5_loss: 0.9542 - val_time_distributed_6_loss: 0.9619 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9985
# 6400/6400 [==============================] - 176s 27ms/step - loss: 7.8999 - time_distributed_1_loss: 0.9987 - time_distributed_2_loss: 0.9801 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9989 - time_distributed_5_loss: 0.9567 - time_distributed_6_loss: 0.9636 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9986 - val_loss: 7.8943 - val_time_distributed_1_loss: 0.9987 - val_time_distributed_2_loss: 0.9792 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9989 - val_time_distributed_5_loss: 0.9542 - val_time_distributed_6_loss: 0.9619 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9985
# Epoch 14/20000
# Epoch 14/20000
# 6400/6400 [==============================] - 176s 27ms/step - loss: 7.8912 - time_distributed_1_loss: 0.9987 - time_distributed_2_loss: 0.9786 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9989 - time_distributed_5_loss: 0.9525 - time_distributed_6_loss: 0.9608 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9985 - val_loss: 7.8851 - val_time_distributed_1_loss: 0.9987 - val_time_distributed_2_loss: 0.9776 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9989 - val_time_distributed_5_loss: 0.9497 - val_time_distributed_6_loss: 0.9590 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9985
# 6400/6400 [==============================] - 176s 27ms/step - loss: 7.8912 - time_distributed_1_loss: 0.9987 - time_distributed_2_loss: 0.9786 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9989 - time_distributed_5_loss: 0.9525 - time_distributed_6_loss: 0.9608 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9985 - val_loss: 7.8851 - val_time_distributed_1_loss: 0.9987 - val_time_distributed_2_loss: 0.9776 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9989 - val_time_distributed_5_loss: 0.9497 - val_time_distributed_6_loss: 0.9590 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9985
# Epoch 15/20000
# Epoch 15/20000
# 6400/6400 [==============================] - 179s 28ms/step - loss: 7.8817 - time_distributed_1_loss: 0.9986 - time_distributed_2_loss: 0.9769 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9988 - time_distributed_5_loss: 0.9480 - time_distributed_6_loss: 0.9578 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9985 - val_loss: 7.8751 - val_time_distributed_1_loss: 0.9986 - val_time_distributed_2_loss: 0.9757 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9988 - val_time_distributed_5_loss: 0.9449 - val_time_distributed_6_loss: 0.9558 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9984
# 6400/6400 [==============================] - 179s 28ms/step - loss: 7.8817 - time_distributed_1_loss: 0.9986 - time_distributed_2_loss: 0.9769 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9988 - time_distributed_5_loss: 0.9480 - time_distributed_6_loss: 0.9578 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9985 - val_loss: 7.8751 - val_time_distributed_1_loss: 0.9986 - val_time_distributed_2_loss: 0.9757 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9988 - val_time_distributed_5_loss: 0.9449 - val_time_distributed_6_loss: 0.9558 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9984
# Epoch 16/20000
# Epoch 16/20000
# 6400/6400 [==============================] - 181s 28ms/step - loss: 7.8714 - time_distributed_1_loss: 0.9986 - time_distributed_2_loss: 0.9750 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9988 - time_distributed_5_loss: 0.9430 - time_distributed_6_loss: 0.9545 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9984 - val_loss: 7.8642 - val_time_distributed_1_loss: 0.9986 - val_time_distributed_2_loss: 0.9737 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9988 - val_time_distributed_5_loss: 0.9396 - val_time_distributed_6_loss: 0.9524 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9984
# 6400/6400 [==============================] - 181s 28ms/step - loss: 7.8714 - time_distributed_1_loss: 0.9986 - time_distributed_2_loss: 0.9750 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9988 - time_distributed_5_loss: 0.9430 - time_distributed_6_loss: 0.9545 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9984 - val_loss: 7.8642 - val_time_distributed_1_loss: 0.9986 - val_time_distributed_2_loss: 0.9737 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9988 - val_time_distributed_5_loss: 0.9396 - val_time_distributed_6_loss: 0.9524 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9984
# Epoch 17/20000
# Epoch 17/20000
# 6400/6400 [==============================] - 173s 27ms/step - loss: 7.8601 - time_distributed_1_loss: 0.9985 - time_distributed_2_loss: 0.9729 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9988 - time_distributed_5_loss: 0.9375 - time_distributed_6_loss: 0.9511 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9984 - val_loss: 7.8523 - val_time_distributed_1_loss: 0.9985 - val_time_distributed_2_loss: 0.9715 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9988 - val_time_distributed_5_loss: 0.9338 - val_time_distributed_6_loss: 0.9488 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9984
# 6400/6400 [==============================] - 173s 27ms/step - loss: 7.8601 - time_distributed_1_loss: 0.9985 - time_distributed_2_loss: 0.9729 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9988 - time_distributed_5_loss: 0.9375 - time_distributed_6_loss: 0.9511 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9984 - val_loss: 7.8523 - val_time_distributed_1_loss: 0.9985 - val_time_distributed_2_loss: 0.9715 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9988 - val_time_distributed_5_loss: 0.9338 - val_time_distributed_6_loss: 0.9488 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9984
# Epoch 18/20000
# Epoch 18/20000
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.8478 - time_distributed_1_loss: 0.9985 - time_distributed_2_loss: 0.9706 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9987 - time_distributed_5_loss: 0.9315 - time_distributed_6_loss: 0.9473 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9983 - val_loss: 7.8395 - val_time_distributed_1_loss: 0.9984 - val_time_distributed_2_loss: 0.9690 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9987 - val_time_distributed_5_loss: 0.9277 - val_time_distributed_6_loss: 0.9449 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9983
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.8478 - time_distributed_1_loss: 0.9985 - time_distributed_2_loss: 0.9706 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9987 - time_distributed_5_loss: 0.9315 - time_distributed_6_loss: 0.9473 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9983 - val_loss: 7.8395 - val_time_distributed_1_loss: 0.9984 - val_time_distributed_2_loss: 0.9690 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9987 - val_time_distributed_5_loss: 0.9277 - val_time_distributed_6_loss: 0.9449 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9983
# Epoch 19/20000
# Epoch 19/20000
# 6400/6400 [==============================] - 173s 27ms/step - loss: 7.8345 - time_distributed_1_loss: 0.9984 - time_distributed_2_loss: 0.9680 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9987 - time_distributed_5_loss: 0.9252 - time_distributed_6_loss: 0.9433 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9983 - val_loss: 7.8257 - val_time_distributed_1_loss: 0.9984 - val_time_distributed_2_loss: 0.9662 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9987 - val_time_distributed_5_loss: 0.9210 - val_time_distributed_6_loss: 0.9407 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9983
# 6400/6400 [==============================] - 173s 27ms/step - loss: 7.8345 - time_distributed_1_loss: 0.9984 - time_distributed_2_loss: 0.9680 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9987 - time_distributed_5_loss: 0.9252 - time_distributed_6_loss: 0.9433 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9983 - val_loss: 7.8257 - val_time_distributed_1_loss: 0.9984 - val_time_distributed_2_loss: 0.9662 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9987 - val_time_distributed_5_loss: 0.9210 - val_time_distributed_6_loss: 0.9407 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9983
# Epoch 20/20000
# Epoch 20/20000
# 6400/6400 [==============================] - 172s 27ms/step - loss: 7.8205 - time_distributed_1_loss: 0.9983 - time_distributed_2_loss: 0.9650 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9987 - time_distributed_5_loss: 0.9184 - time_distributed_6_loss: 0.9390 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9983 - val_loss: 7.8110 - val_time_distributed_1_loss: 0.9983 - val_time_distributed_2_loss: 0.9630 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9986 - val_time_distributed_5_loss: 0.9142 - val_time_distributed_6_loss: 0.9362 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9982
# 6400/6400 [==============================] - 172s 27ms/step - loss: 7.8205 - time_distributed_1_loss: 0.9983 - time_distributed_2_loss: 0.9650 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9987 - time_distributed_5_loss: 0.9184 - time_distributed_6_loss: 0.9390 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9983 - val_loss: 7.8110 - val_time_distributed_1_loss: 0.9983 - val_time_distributed_2_loss: 0.9630 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9986 - val_time_distributed_5_loss: 0.9142 - val_time_distributed_6_loss: 0.9362 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9982
# Epoch 21/20000
# Epoch 21/20000
# 6400/6400 [==============================] - 177s 28ms/step - loss: 7.8055 - time_distributed_1_loss: 0.9982 - time_distributed_2_loss: 0.9617 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9986 - time_distributed_5_loss: 0.9116 - time_distributed_6_loss: 0.9345 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9982 - val_loss: 7.7957 - val_time_distributed_1_loss: 0.9982 - val_time_distributed_2_loss: 0.9595 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9986 - val_time_distributed_5_loss: 0.9072 - val_time_distributed_6_loss: 0.9316 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9982
# 6400/6400 [==============================] - 177s 28ms/step - loss: 7.8055 - time_distributed_1_loss: 0.9982 - time_distributed_2_loss: 0.9617 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9986 - time_distributed_5_loss: 0.9116 - time_distributed_6_loss: 0.9345 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9982 - val_loss: 7.7957 - val_time_distributed_1_loss: 0.9982 - val_time_distributed_2_loss: 0.9595 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9986 - val_time_distributed_5_loss: 0.9072 - val_time_distributed_6_loss: 0.9316 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9982
# Epoch 22/20000
# Epoch 22/20000
# 6400/6400 [==============================] - 173s 27ms/step - loss: 7.7899 - time_distributed_1_loss: 0.9982 - time_distributed_2_loss: 0.9580 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9986 - time_distributed_5_loss: 0.9047 - time_distributed_6_loss: 0.9298 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9982 - val_loss: 7.7798 - val_time_distributed_1_loss: 0.9981 - val_time_distributed_2_loss: 0.9555 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9986 - val_time_distributed_5_loss: 0.9004 - val_time_distributed_6_loss: 0.9267 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9981
# 6400/6400 [==============================] - 173s 27ms/step - loss: 7.7899 - time_distributed_1_loss: 0.9982 - time_distributed_2_loss: 0.9580 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9986 - time_distributed_5_loss: 0.9047 - time_distributed_6_loss: 0.9298 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9982 - val_loss: 7.7798 - val_time_distributed_1_loss: 0.9981 - val_time_distributed_2_loss: 0.9555 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9986 - val_time_distributed_5_loss: 0.9004 - val_time_distributed_6_loss: 0.9267 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9981
# Epoch 23/20000
# Epoch 23/20000
# 6400/6400 [==============================] - 169s 26ms/step - loss: 7.7739 - time_distributed_1_loss: 0.9981 - time_distributed_2_loss: 0.9538 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9986 - time_distributed_5_loss: 0.8980 - time_distributed_6_loss: 0.9248 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9981 - val_loss: 7.7636 - val_time_distributed_1_loss: 0.9980 - val_time_distributed_2_loss: 0.9510 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9985 - val_time_distributed_5_loss: 0.8940 - val_time_distributed_6_loss: 0.9217 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9981
# 6400/6400 [==============================] - 169s 26ms/step - loss: 7.7739 - time_distributed_1_loss: 0.9981 - time_distributed_2_loss: 0.9538 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9986 - time_distributed_5_loss: 0.8980 - time_distributed_6_loss: 0.9248 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9981 - val_loss: 7.7636 - val_time_distributed_1_loss: 0.9980 - val_time_distributed_2_loss: 0.9510 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9985 - val_time_distributed_5_loss: 0.8940 - val_time_distributed_6_loss: 0.9217 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9981
# Epoch 24/20000
# Epoch 24/20000
# 6400/6400 [==============================] - 176s 27ms/step - loss: 7.7576 - time_distributed_1_loss: 0.9980 - time_distributed_2_loss: 0.9492 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9985 - time_distributed_5_loss: 0.8917 - time_distributed_6_loss: 0.9198 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9981 - val_loss: 7.7474 - val_time_distributed_1_loss: 0.9979 - val_time_distributed_2_loss: 0.9459 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9985 - val_time_distributed_5_loss: 0.8882 - val_time_distributed_6_loss: 0.9166 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9980
# 6400/6400 [==============================] - 176s 27ms/step - loss: 7.7576 - time_distributed_1_loss: 0.9980 - time_distributed_2_loss: 0.9492 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9985 - time_distributed_5_loss: 0.8917 - time_distributed_6_loss: 0.9198 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9981 - val_loss: 7.7474 - val_time_distributed_1_loss: 0.9979 - val_time_distributed_2_loss: 0.9459 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9985 - val_time_distributed_5_loss: 0.8882 - val_time_distributed_6_loss: 0.9166 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9980
# Epoch 25/20000
# Epoch 25/20000
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.7415 - time_distributed_1_loss: 0.9979 - time_distributed_2_loss: 0.9439 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9985 - time_distributed_5_loss: 0.8862 - time_distributed_6_loss: 0.9146 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9980 - val_loss: 7.7311 - val_time_distributed_1_loss: 0.9978 - val_time_distributed_2_loss: 0.9402 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9984 - val_time_distributed_5_loss: 0.8831 - val_time_distributed_6_loss: 0.9114 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9980
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.7415 - time_distributed_1_loss: 0.9979 - time_distributed_2_loss: 0.9439 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9985 - time_distributed_5_loss: 0.8862 - time_distributed_6_loss: 0.9146 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9980 - val_loss: 7.7311 - val_time_distributed_1_loss: 0.9978 - val_time_distributed_2_loss: 0.9402 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9984 - val_time_distributed_5_loss: 0.8831 - val_time_distributed_6_loss: 0.9114 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9980
# Epoch 26/20000
# Epoch 26/20000
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.7253 - time_distributed_1_loss: 0.9978 - time_distributed_2_loss: 0.9379 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9984 - time_distributed_5_loss: 0.8814 - time_distributed_6_loss: 0.9094 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9980 - val_loss: 7.7149 - val_time_distributed_1_loss: 0.9977 - val_time_distributed_2_loss: 0.9338 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9984 - val_time_distributed_5_loss: 0.8787 - val_time_distributed_6_loss: 0.9062 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9979
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.7253 - time_distributed_1_loss: 0.9978 - time_distributed_2_loss: 0.9379 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9984 - time_distributed_5_loss: 0.8814 - time_distributed_6_loss: 0.9094 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9980 - val_loss: 7.7149 - val_time_distributed_1_loss: 0.9977 - val_time_distributed_2_loss: 0.9338 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9984 - val_time_distributed_5_loss: 0.8787 - val_time_distributed_6_loss: 0.9062 - val_time_distributed_7_loss: 0.9995 - val_time_distributed_8_loss: 0.9979
# Epoch 27/20000
# Epoch 27/20000
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.7090 - time_distributed_1_loss: 0.9976 - time_distributed_2_loss: 0.9311 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9984 - time_distributed_5_loss: 0.8773 - time_distributed_6_loss: 0.9043 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9979 - val_loss: 7.6986 - val_time_distributed_1_loss: 0.9976 - val_time_distributed_2_loss: 0.9266 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9984 - val_time_distributed_5_loss: 0.8750 - val_time_distributed_6_loss: 0.9012 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9979
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.7090 - time_distributed_1_loss: 0.9976 - time_distributed_2_loss: 0.9311 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9984 - time_distributed_5_loss: 0.8773 - time_distributed_6_loss: 0.9043 - time_distributed_7_loss: 0.9995 - time_distributed_8_loss: 0.9979 - val_loss: 7.6986 - val_time_distributed_1_loss: 0.9976 - val_time_distributed_2_loss: 0.9266 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9984 - val_time_distributed_5_loss: 0.8750 - val_time_distributed_6_loss: 0.9012 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9979
# Epoch 28/20000
# Epoch 28/20000
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.6927 - time_distributed_1_loss: 0.9975 - time_distributed_2_loss: 0.9236 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9983 - time_distributed_5_loss: 0.8737 - time_distributed_6_loss: 0.8994 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9978 - val_loss: 7.6821 - val_time_distributed_1_loss: 0.9974 - val_time_distributed_2_loss: 0.9184 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9983 - val_time_distributed_5_loss: 0.8718 - val_time_distributed_6_loss: 0.8963 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9978
# 6400/6400 [==============================] - 174s 27ms/step - loss: 7.6927 - time_distributed_1_loss: 0.9975 - time_distributed_2_loss: 0.9236 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9983 - time_distributed_5_loss: 0.8737 - time_distributed_6_loss: 0.8994 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9978 - val_loss: 7.6821 - val_time_distributed_1_loss: 0.9974 - val_time_distributed_2_loss: 0.9184 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9983 - val_time_distributed_5_loss: 0.8718 - val_time_distributed_6_loss: 0.8963 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9978
# Epoch 29/20000
# Epoch 29/20000
# 6400/6400 [==============================] - 166s 26ms/step - loss: 7.6760 - time_distributed_1_loss: 0.9974 - time_distributed_2_loss: 0.9151 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9983 - time_distributed_5_loss: 0.8707 - time_distributed_6_loss: 0.8945 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9978 - val_loss: 7.6654 - val_time_distributed_1_loss: 0.9973 - val_time_distributed_2_loss: 0.9094 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9983 - val_time_distributed_5_loss: 0.8689 - val_time_distributed_6_loss: 0.8917 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9978
# 6400/6400 [==============================] - 166s 26ms/step - loss: 7.6760 - time_distributed_1_loss: 0.9974 - time_distributed_2_loss: 0.9151 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9983 - time_distributed_5_loss: 0.8707 - time_distributed_6_loss: 0.8945 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9978 - val_loss: 7.6654 - val_time_distributed_1_loss: 0.9973 - val_time_distributed_2_loss: 0.9094 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9983 - val_time_distributed_5_loss: 0.8689 - val_time_distributed_6_loss: 0.8917 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9978
# Epoch 30/20000
# Epoch 30/20000
# 6400/6400 [==============================] - 168s 26ms/step - loss: 7.6590 - time_distributed_1_loss: 0.9972 - time_distributed_2_loss: 0.9056 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9983 - time_distributed_5_loss: 0.8679 - time_distributed_6_loss: 0.8900 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9977 - val_loss: 7.6480 - val_time_distributed_1_loss: 0.9971 - val_time_distributed_2_loss: 0.8993 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9982 - val_time_distributed_5_loss: 0.8663 - val_time_distributed_6_loss: 0.8874 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9977
# 6400/6400 [==============================] - 168s 26ms/step - loss: 7.6590 - time_distributed_1_loss: 0.9972 - time_distributed_2_loss: 0.9056 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9983 - time_distributed_5_loss: 0.8679 - time_distributed_6_loss: 0.8900 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9977 - val_loss: 7.6480 - val_time_distributed_1_loss: 0.9971 - val_time_distributed_2_loss: 0.8993 - val_time_distributed_3_loss: 0.9997 - val_time_distributed_4_loss: 0.9982 - val_time_distributed_5_loss: 0.8663 - val_time_distributed_6_loss: 0.8874 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9977
# Epoch 31/20000
# Epoch 31/20000
# 6400/6400 [==============================] - 181s 28ms/step - loss: 7.6415 - time_distributed_1_loss: 0.9971 - time_distributed_2_loss: 0.8951 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9982 - time_distributed_5_loss: 0.8653 - time_distributed_6_loss: 0.8859 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9977 - val_loss: 7.6299 - val_time_distributed_1_loss: 0.9969 - val_time_distributed_2_loss: 0.8880 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9982 - val_time_distributed_5_loss: 0.8637 - val_time_distributed_6_loss: 0.8834 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9976
# 6400/6400 [==============================] - 181s 28ms/step - loss: 7.6415 - time_distributed_1_loss: 0.9971 - time_distributed_2_loss: 0.8951 - time_distributed_3_loss: 0.9997 - time_distributed_4_loss: 0.9982 - time_distributed_5_loss: 0.8653 - time_distributed_6_loss: 0.8859 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9977 - val_loss: 7.6299 - val_time_distributed_1_loss: 0.9969 - val_time_distributed_2_loss: 0.8880 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9982 - val_time_distributed_5_loss: 0.8637 - val_time_distributed_6_loss: 0.8834 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9976
# Epoch 32/20000
# Epoch 32/20000
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.6230 - time_distributed_1_loss: 0.9969 - time_distributed_2_loss: 0.8834 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9981 - time_distributed_5_loss: 0.8628 - time_distributed_6_loss: 0.8820 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9976 - val_loss: 7.6108 - val_time_distributed_1_loss: 0.9967 - val_time_distributed_2_loss: 0.8755 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9981 - val_time_distributed_5_loss: 0.8612 - val_time_distributed_6_loss: 0.8797 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9976
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.6230 - time_distributed_1_loss: 0.9969 - time_distributed_2_loss: 0.8834 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9981 - time_distributed_5_loss: 0.8628 - time_distributed_6_loss: 0.8820 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9976 - val_loss: 7.6108 - val_time_distributed_1_loss: 0.9967 - val_time_distributed_2_loss: 0.8755 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9981 - val_time_distributed_5_loss: 0.8612 - val_time_distributed_6_loss: 0.8797 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9976
# Epoch 33/20000
# Epoch 33/20000
# 6400/6400 [==============================] - 188s 29ms/step - loss: 7.6035 - time_distributed_1_loss: 0.9967 - time_distributed_2_loss: 0.8704 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9981 - time_distributed_5_loss: 0.8603 - time_distributed_6_loss: 0.8783 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9975 - val_loss: 7.5907 - val_time_distributed_1_loss: 0.9965 - val_time_distributed_2_loss: 0.8618 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9981 - val_time_distributed_5_loss: 0.8587 - val_time_distributed_6_loss: 0.8761 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9975
# 6400/6400 [==============================] - 188s 29ms/step - loss: 7.6035 - time_distributed_1_loss: 0.9967 - time_distributed_2_loss: 0.8704 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9981 - time_distributed_5_loss: 0.8603 - time_distributed_6_loss: 0.8783 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9975 - val_loss: 7.5907 - val_time_distributed_1_loss: 0.9965 - val_time_distributed_2_loss: 0.8618 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9981 - val_time_distributed_5_loss: 0.8587 - val_time_distributed_6_loss: 0.8761 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9975
# Epoch 34/20000
# Epoch 34/20000
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.5830 - time_distributed_1_loss: 0.9964 - time_distributed_2_loss: 0.8562 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9980 - time_distributed_5_loss: 0.8577 - time_distributed_6_loss: 0.8749 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9975 - val_loss: 7.5693 - val_time_distributed_1_loss: 0.9963 - val_time_distributed_2_loss: 0.8466 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9980 - val_time_distributed_5_loss: 0.8561 - val_time_distributed_6_loss: 0.8728 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9974
# 6400/6400 [==============================] - 178s 28ms/step - loss: 7.5830 - time_distributed_1_loss: 0.9964 - time_distributed_2_loss: 0.8562 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9980 - time_distributed_5_loss: 0.8577 - time_distributed_6_loss: 0.8749 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9975 - val_loss: 7.5693 - val_time_distributed_1_loss: 0.9963 - val_time_distributed_2_loss: 0.8466 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9980 - val_time_distributed_5_loss: 0.8561 - val_time_distributed_6_loss: 0.8728 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9974
# Epoch 35/20000
# Epoch 35/20000
# 6400/6400 [==============================] - 171s 27ms/step - loss: 7.5611 - time_distributed_1_loss: 0.9962 - time_distributed_2_loss: 0.8406 - time_distributed_3_loss: 0.9996 - time_distributed_4_loss: 0.9980 - time_distributed_5_loss: 0.8552 - time_distributed_6_loss: 0.8716 - time_distributed_7_loss: 0.9994 - time_distributed_8_loss: 0.9974 - val_loss: 7.5466 - val_time_distributed_1_loss: 0.9960 - val_time_distributed_2_loss: 0.8302 - val_time_distributed_3_loss: 0.9996 - val_time_distributed_4_loss: 0.9979 - val_time_distributed_5_loss: 0.8536 - val_time_distributed_6_loss: 0.8695 - val_time_distributed_7_loss: 0.9994 - val_time_distributed_8_loss: 0.9974
# ...
# Epoch 506/20000
# Epoch 506/20000
# 6400/6400 [==============================] - 177s 28ms/step - loss: 2.4258 - time_distributed_1_loss: 0.2722 - time_distributed_2_loss: 0.1279 - time_distributed_3_loss: 0.0504 - time_distributed_4_loss: 0.5737 - time_distributed_5_loss: 0.2683 - time_distributed_6_loss: 0.2400 - time_distributed_7_loss: 0.0905 - time_distributed_8_loss: 0.7040 - val_loss: 2.4227 - val_time_distributed_1_loss: 0.2715 - val_time_distributed_2_loss: 0.1270 - val_time_distributed_3_loss: 0.0513 - val_time_distributed_4_loss: 0.5734 - val_time_distributed_5_loss: 0.2676 - val_time_distributed_6_loss: 0.2381 - val_time_distributed_7_loss: 0.0908 - val_time_distributed_8_loss: 0.7056
# 6400/6400 [==============================] - 177s 28ms/step - loss: 2.4258 - time_distributed_1_loss: 0.2722 - time_distributed_2_loss: 0.1279 - time_distributed_3_loss: 0.0504 - time_distributed_4_loss: 0.5737 - time_distributed_5_loss: 0.2683 - time_distributed_6_loss: 0.2400 - time_distributed_7_loss: 0.0905 - time_distributed_8_loss: 0.7040 - val_loss: 2.4227 - val_time_distributed_1_loss: 0.2715 - val_time_distributed_2_loss: 0.1270 - val_time_distributed_3_loss: 0.0513 - val_time_distributed_4_loss: 0.5734 - val_time_distributed_5_loss: 0.2676 - val_time_distributed_6_loss: 0.2381 - val_time_distributed_7_loss: 0.0908 - val_time_distributed_8_loss: 0.7056
# Epoch 507/20000
# Epoch 507/20000
# 6400/6400 [==============================] - 170s 27ms/step - loss: 2.4194 - time_distributed_1_loss: 0.2713 - time_distributed_2_loss: 0.1245 - time_distributed_3_loss: 0.0509 - time_distributed_4_loss: 0.5733 - time_distributed_5_loss: 0.2679 - time_distributed_6_loss: 0.2377 - time_distributed_7_loss: 0.0905 - time_distributed_8_loss: 0.7050 - val_loss: 2.4142 - val_time_distributed_1_loss: 0.2718 - val_time_distributed_2_loss: 0.1205 - val_time_distributed_3_loss: 0.0505 - val_time_distributed_4_loss: 0.5738 - val_time_distributed_5_loss: 0.2668 - val_time_distributed_6_loss: 0.2389 - val_time_distributed_7_loss: 0.0905 - val_time_distributed_8_loss: 0.7035
# 6400/6400 [==============================] - 170s 27ms/step - loss: 2.4194 - time_distributed_1_loss: 0.2713 - time_distributed_2_loss: 0.1245 - time_distributed_3_loss: 0.0509 - time_distributed_4_loss: 0.5733 - time_distributed_5_loss: 0.2679 - time_distributed_6_loss: 0.2377 - time_distributed_7_loss: 0.0905 - time_distributed_8_loss: 0.7050 - val_loss: 2.4142 - val_time_distributed_1_loss: 0.2718 - val_time_distributed_2_loss: 0.1205 - val_time_distributed_3_loss: 0.0505 - val_time_distributed_4_loss: 0.5738 - val_time_distributed_5_loss: 0.2668 - val_time_distributed_6_loss: 0.2389 - val_time_distributed_7_loss: 0.0905 - val_time_distributed_8_loss: 0.7035
# Epoch 508/20000
# Epoch 508/20000
# 6400/6400 [==============================] - 176s 28ms/step - loss: 2.4154 - time_distributed_1_loss: 0.2712 - time_distributed_2_loss: 0.1217 - time_distributed_3_loss: 0.0505 - time_distributed_4_loss: 0.5735 - time_distributed_5_loss: 0.2676 - time_distributed_6_loss: 0.2381 - time_distributed_7_loss: 0.0906 - time_distributed_8_loss: 0.7037 - val_loss: 2.4133 - val_time_distributed_1_loss: 0.2712 - val_time_distributed_2_loss: 0.1207 - val_time_distributed_3_loss: 0.0511 - val_time_distributed_4_loss: 0.5730 - val_time_distributed_5_loss: 0.2681 - val_time_distributed_6_loss: 0.2382 - val_time_distributed_7_loss: 0.0904 - val_time_distributed_8_loss: 0.7031
# 6400/6400 [==============================] - 176s 28ms/step - loss: 2.4154 - time_distributed_1_loss: 0.2712 - time_distributed_2_loss: 0.1217 - time_distributed_3_loss: 0.0505 - time_distributed_4_loss: 0.5735 - time_distributed_5_loss: 0.2676 - time_distributed_6_loss: 0.2381 - time_distributed_7_loss: 0.0906 - time_distributed_8_loss: 0.7037 - val_loss: 2.4133 - val_time_distributed_1_loss: 0.2712 - val_time_distributed_2_loss: 0.1207 - val_time_distributed_3_loss: 0.0511 - val_time_distributed_4_loss: 0.5730 - val_time_distributed_5_loss: 0.2681 - val_time_distributed_6_loss: 0.2382 - val_time_distributed_7_loss: 0.0904 - val_time_distributed_8_loss: 0.7031
# Epoch 509/20000
# Epoch 509/20000
# 6400/6400 [==============================] - 171s 27ms/step - loss: 2.4134 - time_distributed_1_loss: 0.2707 - time_distributed_2_loss: 0.1211 - time_distributed_3_loss: 0.0506 - time_distributed_4_loss: 0.5732 - time_distributed_5_loss: 0.2673 - time_distributed_6_loss: 0.2382 - time_distributed_7_loss: 0.0904 - time_distributed_8_loss: 0.7033 - val_loss: 2.4119 - val_time_distributed_1_loss: 0.2707 - val_time_distributed_2_loss: 0.1212 - val_time_distributed_3_loss: 0.0499 - val_time_distributed_4_loss: 0.5725 - val_time_distributed_5_loss: 0.2670 - val_time_distributed_6_loss: 0.2400 - val_time_distributed_7_loss: 0.0902 - val_time_distributed_8_loss: 0.7030
# 6400/6400 [==============================] - 171s 27ms/step - loss: 2.4134 - time_distributed_1_loss: 0.2707 - time_distributed_2_loss: 0.1211 - time_distributed_3_loss: 0.0506 - time_distributed_4_loss: 0.5732 - time_distributed_5_loss: 0.2673 - time_distributed_6_loss: 0.2382 - time_distributed_7_loss: 0.0904 - time_distributed_8_loss: 0.7033 - val_loss: 2.4119 - val_time_distributed_1_loss: 0.2707 - val_time_distributed_2_loss: 0.1212 - val_time_distributed_3_loss: 0.0499 - val_time_distributed_4_loss: 0.5725 - val_time_distributed_5_loss: 0.2670 - val_time_distributed_6_loss: 0.2400 - val_time_distributed_7_loss: 0.0902 - val_time_distributed_8_loss: 0.7030
# Epoch 510/20000
# Epoch 510/20000
# 6400/6400 [==============================] - 173s 27ms/step - loss: 2.4130 - time_distributed_1_loss: 0.2704 - time_distributed_2_loss: 0.1226 - time_distributed_3_loss: 0.0499 - time_distributed_4_loss: 0.5730 - time_distributed_5_loss: 0.2679 - time_distributed_6_loss: 0.2375 - time_distributed_7_loss: 0.0902 - time_distributed_8_loss: 0.7030 - val_loss: 2.4225 - val_time_distributed_1_loss: 0.2700 - val_time_distributed_2_loss: 0.1250 - val_time_distributed_3_loss: 0.0499 - val_time_distributed_4_loss: 0.5744 - val_time_distributed_5_loss: 0.2693 - val_time_distributed_6_loss: 0.2435 - val_time_distributed_7_loss: 0.0903 - val_time_distributed_8_loss: 0.7029
# 6400/6400 [==============================] - 173s 27ms/step - loss: 2.4130 - time_distributed_1_loss: 0.2704 - time_distributed_2_loss: 0.1226 - time_distributed_3_loss: 0.0499 - time_distributed_4_loss: 0.5730 - time_distributed_5_loss: 0.2679 - time_distributed_6_loss: 0.2375 - time_distributed_7_loss: 0.0902 - time_distributed_8_loss: 0.7030 - val_loss: 2.4225 - val_time_distributed_1_loss: 0.2700 - val_time_distributed_2_loss: 0.1250 - val_time_distributed_3_loss: 0.0499 - val_time_distributed_4_loss: 0.5744 - val_time_distributed_5_loss: 0.2693 - val_time_distributed_6_loss: 0.2435 - val_time_distributed_7_loss: 0.0903 - val_time_distributed_8_loss: 0.7029
# Epoch 511/20000
# Epoch 511/20000
# 6400/6400 [==============================] - 179s 28ms/step - loss: 2.4162 - time_distributed_1_loss: 0.2703 - time_distributed_2_loss: 0.1232 - time_distributed_3_loss: 0.0500 - time_distributed_4_loss: 0.5733 - time_distributed_5_loss: 0.2683 - time_distributed_6_loss: 0.2399 - time_distributed_7_loss: 0.0901 - time_distributed_8_loss: 0.7034 - val_loss: 2.4114 - val_time_distributed_1_loss: 0.2702 - val_time_distributed_2_loss: 0.1226 - val_time_distributed_3_loss: 0.0503 - val_time_distributed_4_loss: 0.5736 - val_time_distributed_5_loss: 0.2663 - val_time_distributed_6_loss: 0.2380 - val_time_distributed_7_loss: 0.0900 - val_time_distributed_8_loss: 0.7030
# 6400/6400 [==============================] - 179s 28ms/step - loss: 2.4162 - time_distributed_1_loss: 0.2703 - time_distributed_2_loss: 0.1232 - time_distributed_3_loss: 0.0500 - time_distributed_4_loss: 0.5733 - time_distributed_5_loss: 0.2683 - time_distributed_6_loss: 0.2399 - time_distributed_7_loss: 0.0901 - time_distributed_8_loss: 0.7034 - val_loss: 2.4114 - val_time_distributed_1_loss: 0.2702 - val_time_distributed_2_loss: 0.1226 - val_time_distributed_3_loss: 0.0503 - val_time_distributed_4_loss: 0.5736 - val_time_distributed_5_loss: 0.2663 - val_time_distributed_6_loss: 0.2380 - val_time_distributed_7_loss: 0.0900 - val_time_distributed_8_loss: 0.7030
# Epoch 512/20000
# Epoch 512/20000
# 6400/6400 [==============================] - 170s 27ms/step - loss: 2.4107 - time_distributed_1_loss: 0.2700 - time_distributed_2_loss: 0.1222 - time_distributed_3_loss: 0.0501 - time_distributed_4_loss: 0.5730 - time_distributed_5_loss: 0.2675 - time_distributed_6_loss: 0.2370 - time_distributed_7_loss: 0.0902 - time_distributed_8_loss: 0.7026 - val_loss: 2.4207 - val_time_distributed_1_loss: 0.2701 - val_time_distributed_2_loss: 0.1277 - val_time_distributed_3_loss: 0.0501 - val_time_distributed_4_loss: 0.5757 - val_time_distributed_5_loss: 0.2703 - val_time_distributed_6_loss: 0.2368 - val_time_distributed_7_loss: 0.0900 - val_time_distributed_8_loss: 0.7035
# 6400/6400 [==============================] - 170s 27ms/step - loss: 2.4107 - time_distributed_1_loss: 0.2700 - time_distributed_2_loss: 0.1222 - time_distributed_3_loss: 0.0501 - time_distributed_4_loss: 0.5730 - time_distributed_5_loss: 0.2675 - time_distributed_6_loss: 0.2370 - time_distributed_7_loss: 0.0902 - time_distributed_8_loss: 0.7026 - val_loss: 2.4207 - val_time_distributed_1_loss: 0.2701 - val_time_distributed_2_loss: 0.1277 - val_time_distributed_3_loss: 0.0501 - val_time_distributed_4_loss: 0.5757 - val_time_distributed_5_loss: 0.2703 - val_time_distributed_6_loss: 0.2368 - val_time_distributed_7_loss: 0.0900 - val_time_distributed_8_loss: 0.7035
# Epoch 513/20000
# Epoch 513/20000
# 6400/6400 [==============================] - 172s 27ms/step - loss: 2.4130 - time_distributed_1_loss: 0.2701 - time_distributed_2_loss: 0.1223 - time_distributed_3_loss: 0.0499 - time_distributed_4_loss: 0.5732 - time_distributed_5_loss: 0.2681 - time_distributed_6_loss: 0.2385 - time_distributed_7_loss: 0.0901 - time_distributed_8_loss: 0.7033 - val_loss: 2.4079 - val_time_distributed_1_loss: 0.2696 - val_time_distributed_2_loss: 0.1207 - val_time_distributed_3_loss: 0.0498 - val_time_distributed_4_loss: 0.5737 - val_time_distributed_5_loss: 0.2669 - val_time_distributed_6_loss: 0.2376 - val_time_distributed_7_loss: 0.0900 - val_time_distributed_8_loss: 0.7028
# 6400/6400 [==============================] - 172s 27ms/step - loss: 2.4130 - time_distributed_1_loss: 0.2701 - time_distributed_2_loss: 0.1223 - time_distributed_3_loss: 0.0499 - time_distributed_4_loss: 0.5732 - time_distributed_5_loss: 0.2681 - time_distributed_6_loss: 0.2385 - time_distributed_7_loss: 0.0901 - time_distributed_8_loss: 0.7033 - val_loss: 2.4079 - val_time_distributed_1_loss: 0.2696 - val_time_distributed_2_loss: 0.1207 - val_time_distributed_3_loss: 0.0498 - val_time_distributed_4_loss: 0.5737 - val_time_distributed_5_loss: 0.2669 - val_time_distributed_6_loss: 0.2376 - val_time_distributed_7_loss: 0.0900 - val_time_distributed_8_loss: 0.7028
# Epoch 514/20000
# Epoch 514/20000
# 6400/6400 [==============================] - 181s 28ms/step - loss: 2.4106 - time_distributed_1_loss: 0.2695 - time_distributed_2_loss: 0.1213 - time_distributed_3_loss: 0.0499 - time_distributed_4_loss: 0.5728 - time_distributed_5_loss: 0.2671 - time_distributed_6_loss: 0.2396 - time_distributed_7_loss: 0.0900 - time_distributed_8_loss: 0.7027 - val_loss: 2.4064 - val_time_distributed_1_loss: 0.2688 - val_time_distributed_2_loss: 0.1216 - val_time_distributed_3_loss: 0.0495 - val_time_distributed_4_loss: 0.5729 - val_time_distributed_5_loss: 0.2681 - val_time_distributed_6_loss: 0.2360 - val_time_distributed_7_loss: 0.0898 - val_time_distributed_8_loss: 0.7025
# 6400/6400 [==============================] - 181s 28ms/step - loss: 2.4106 - time_distributed_1_loss: 0.2695 - time_distributed_2_loss: 0.1213 - time_distributed_3_loss: 0.0499 - time_distributed_4_loss: 0.5728 - time_distributed_5_loss: 0.2671 - time_distributed_6_loss: 0.2396 - time_distributed_7_loss: 0.0900 - time_distributed_8_loss: 0.7027 - val_loss: 2.4064 - val_time_distributed_1_loss: 0.2688 - val_time_distributed_2_loss: 0.1216 - val_time_distributed_3_loss: 0.0495 - val_time_distributed_4_loss: 0.5729 - val_time_distributed_5_loss: 0.2681 - val_time_distributed_6_loss: 0.2360 - val_time_distributed_7_loss: 0.0898 - val_time_distributed_8_loss: 0.7025
# Epoch 515/20000
# Epoch 515/20000
# 6400/6400 [==============================] - 173s 27ms/step - loss: 2.4107 - time_distributed_1_loss: 0.2690 - time_distributed_2_loss: 0.1238 - time_distributed_3_loss: 0.0496 - time_distributed_4_loss: 0.5730 - time_distributed_5_loss: 0.2671 - time_distributed_6_loss: 0.2371 - time_distributed_7_loss: 0.0899 - time_distributed_8_loss: 0.7026 - val_loss: 2.4115 - val_time_distributed_1_loss: 0.2694 - val_time_distributed_2_loss: 0.1252 - val_time_distributed_3_loss: 0.0497 - val_time_distributed_4_loss: 0.5732 - val_time_distributed_5_loss: 0.2666 - val_time_distributed_6_loss: 0.2368 - val_time_distributed_7_loss: 0.0901 - val_time_distributed_8_loss: 0.7036
# 6400/6400 [==============================] - 173s 27ms/step - loss: 2.4107 - time_distributed_1_loss: 0.2690 - time_distributed_2_loss: 0.1238 - time_distributed_3_loss: 0.0496 - time_distributed_4_loss: 0.5730 - time_distributed_5_loss: 0.2671 - time_distributed_6_loss: 0.2371 - time_distributed_7_loss: 0.0899 - time_distributed_8_loss: 0.7026 - val_loss: 2.4115 - val_time_distributed_1_loss: 0.2694 - val_time_distributed_2_loss: 0.1252 - val_time_distributed_3_loss: 0.0497 - val_time_distributed_4_loss: 0.5732 - val_time_distributed_5_loss: 0.2666 - val_time_distributed_6_loss: 0.2368 - val_time_distributed_7_loss: 0.0901 - val_time_distributed_8_loss: 0.7036
# Epoch 516/20000
# Epoch 516/20000
# 6400/6400 [==============================] - 167s 26ms/step - loss: 2.4092 - time_distributed_1_loss: 0.2689 - time_distributed_2_loss: 0.1219 - time_distributed_3_loss: 0.0496 - time_distributed_4_loss: 0.5728 - time_distributed_5_loss: 0.2673 - time_distributed_6_loss: 0.2382 - time_distributed_7_loss: 0.0899 - time_distributed_8_loss: 0.7031 - val_loss: 2.4023 - val_time_distributed_1_loss: 0.2681 - val_time_distributed_2_loss: 0.1200 - val_time_distributed_3_loss: 0.0495 - val_time_distributed_4_loss: 0.5713 - val_time_distributed_5_loss: 0.2683 - val_time_distributed_6_loss: 0.2364 - val_time_distributed_7_loss: 0.0898 - val_time_distributed_8_loss: 0.7022
# 6400/6400 [==============================] - 167s 26ms/step - loss: 2.4092 - time_distributed_1_loss: 0.2689 - time_distributed_2_loss: 0.1219 - time_distributed_3_loss: 0.0496 - time_distributed_4_loss: 0.5728 - time_distributed_5_loss: 0.2673 - time_distributed_6_loss: 0.2382 - time_distributed_7_loss: 0.0899 - time_distributed_8_loss: 0.7031 - val_loss: 2.4023 - val_time_distributed_1_loss: 0.2681 - val_time_distributed_2_loss: 0.1200 - val_time_distributed_3_loss: 0.0495 - val_time_distributed_4_loss: 0.5713 - val_time_distributed_5_loss: 0.2683 - val_time_distributed_6_loss: 0.2364 - val_time_distributed_7_loss: 0.0898 - val_time_distributed_8_loss: 0.7022
# Epoch 517/20000
# Epoch 517/20000
# 5120/6400 [=======================>......] - ETA: 25s - loss: 2.4272 - time_distributed_1_loss: 0.2685 - time_distributed_2_loss: 0.1206 - time_distributed_3_loss: 0.0498 - time_distributed_4_loss: 0.5764 - time_distributed_5_loss: 0.2693 - time_distributed_6_loss: 0.2402 - time_distributed_7_loss: 0.0912 - time_distributed_8_loss: 0.7098

# %%
model.save('./' + Path + '/end')

# %%
dc_vec[0:128].shape

# %%
model.summary()

# %%
e = Nd_mat["Amplitude [V]"][:,:,:,1,2].reshape(-1,128)

h5_sho_spec_inds = px.hdf_utils.getAuxData(h5_sho_fit, auxDataName='Spectroscopic_Indices')[0]
h5_sho_spec_vals = px.hdf_utils.getAuxData(h5_sho_fit, auxDataName='Spectroscopic_Values')[0]

voltage_reshape = h5_sho_spec_vals[1] + h5_sho_spec_vals[2]

voltage_reshape.shape

dc_vec=dc_vec[::124]
plt.plot(dc_vec[0:128],amp_off[100])

# %%
h5_file = h5_main.file
h5_spec_vals = h5_file[px.io.hdf_utils.get_attr(h5_main, 'Spectroscopic_Values')]
 
dc_vec = np.squeeze(h5_spec_vals[h5_spec_vals.attrs['DC_Offset']])

# %%
model = Model(inputs=input_off_amp, outputs=out)

# %%
type(e)

# %%
model.summary()

# %%
from keras.utils import multi_gpu_model

# Replicates `model` on 8 GPUs.
# This assumes that your machine has 8 available GPUs.
parallel_model = multi_gpu_model(model, gpus=8)
parallel_model.compile(loss='categorical_crossentropy',
                       optimizer='rmsprop')

# This `fit` call will be distributed on 8 GPUs.
# Since the batch size is 256, each GPU will process 32 samples.
parallel_model.fit(x, y, epochs=20, batch_size=256)
